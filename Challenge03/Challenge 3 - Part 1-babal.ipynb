# %% [markdown]
# ## Set experiment folder
#
# **NOTE:** This template notebook assume you have succcessfully ran through Challenge 2. You should already have a train.py, driver_training.py, along with a parameters.json in an experiments folder. Using this template, it'll create another script file for registrating the model called registration.py that'll be added to the experiment folder (defined in the cell below).

# %%
# Set the folder for the experiment files used in Challenge 2
training_folder = 'driver-training'

# %% [markdown]
# ## register_model.py
# This file loads the model from where it was saved, and then registers it in the workspace.

# %%
# %%writefile $training_folder/register_model.py
# Import libraries
import argparse
import joblib
from azureml.core import Workspace, Model, Run

# Get parameters
parser = argparse.ArgumentParser()
parser.add_argument(
    '--model_folder',
    type=str,
    dest='model_folder',
    default="driver_model",
    help='model location')
args = parser.parse_args()
model_folder = args.model_folder

# Get the experiment run context
run = Run.get_context()

# Load the model
print("Loading model from " + model_folder)
model_file = model_folder + "/driver_model.pkl"
model = joblib.load(model_file)

Model.register(workspace=run.experiment.workspace,
               model_path = model_file,
               model_name = 'driver_model',
               tags={'Training context':'Pipeline'})

run.complete()
# Out:
# Overwriting driver-training/register_model.py

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace
ws = Workspace.from_config()

# %% [markdown]
# ## Create an Azure Machine Learning Pipeline to Run the Scripts as a Pipeline
#
# See [this tutorial](https://github.com/MicrosoftDocs/mslearn-aml-labs/blob/master/05-Creating_a_Pipeline.ipynb) for a starting point
#
# Use the scikit-learn and lightgbm conda packages

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

# Verify that the compute cluster exists
# If not, create it
## TODO
cluster_name = "team5hacker2"

# Verify that cluster exists
try:
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If not, create it
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',
                                                           max_nodes=4,
                                                           idle_seconds_before_scaledown=1800)
    pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)

pipeline_cluster.wait_for_completion(show_output=True)
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies
from azureml.core.runconfig import RunConfiguration

# Create a Python environment for the experiment
# Let Azure ML manage dependencies by setting user_managed_dependencies to False
# Use docker containers by setting docker.enabled to True 
## TODO
diabetes_env = Environment("driver-pipeline-env")
diabetes_env.python.user_managed_dependencies = False # Let Azure ML manage dependencies
diabetes_env.docker.enabled = True # Use a docker container

# Create a the pip and conda package dependencies
## TODO
driver_packages = CondaDependencies.create(conda_packages=['scikit-learn','pandas','lightgbm'],
                                             pip_packages=['azureml-sdk'])

# Add the package dependencies to the Python environment for the experiment
## TODO
diabetes_env.python.conda_dependencies = driver_packages

# Register the environment 
## TODO
diabetes_env.register(workspace=ws)
registered_env = Environment.get(ws, 'driver-pipeline-env')

# Create a new runconfig object for the pipeline
## TODO
pipeline_run_config = RunConfiguration()

# Assign the target of the runconfig object to the cluster created above  
## TODO
pipeline_run_config.target = pipeline_cluster

# Assign the environment of the runconfig object to the registered environment
## TODO
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep, EstimatorStep
from azureml.train.estimator import Estimator

# Create a PipelineData (temporary Data Reference) for the model folder
## TODO
training_folder = 'driver-training'
experiment_folder = 'driver-training'
model_folder = PipelineData("model_folder", datastore=ws.get_default_datastore())

diabetes_ds = ws.datasets.get("driver dataset")

# Create Estimator to train the model as in Challenge 2
## TODO
estimator = Estimator(source_directory=training_folder,
                        compute_target = pipeline_cluster,
                        environment_definition=pipeline_run_config.environment,
                        entry_script='driver_training.py')

# Create Step 1, which runs the estimator to train the model
## TODO
train_step = EstimatorStep(name = "Train Model",
                           estimator=estimator, 
                           estimator_entry_script_arguments=['--output_folder', model_folder],
                           inputs=[diabetes_ds.as_named_input('driver_train')],
                           outputs=[model_folder],
                           compute_target = pipeline_cluster,
                           allow_reuse = True)
# Create Step 2, which runs the model registration script
## TODO
register_step = PythonScriptStep(name = "Register Model",
                                source_directory = experiment_folder,
                                script_name = "register_model.py",
                                arguments = ['--model_folder', model_folder],
                                inputs=[model_folder],
                                compute_target = pipeline_cluster,
                                runconfig = pipeline_run_config,
                                allow_reuse = True)

print("Pipeline steps defined")
# Out:
# Pipeline steps defined

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline
from azureml.widgets import RunDetails

# Construct the pipeline, which contains Step 1 & 2
## TODO

# Create an experiment and run the pipeline
## TODO

# Construct the pipeline
pipeline_steps = [train_step, register_step]
pipeline = Pipeline(workspace = ws, steps=pipeline_steps)
print("Pipeline is built.")

# Create an experiment and run the pipeline
experiment = Experiment(workspace = ws, name = 'driver-training-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")

RunDetails(pipeline_run).show()
pipeline_run.wait_for_completion()
# Out:
# Pipeline is built.
# Created step Train Model [8517720d][7003a134-8b49-4efb-9382-25bd7973ad52], (This step will run and generate new outputs)
# Created step Register Model [c9f80262][570e562e-9f5a-4694-aa4d-49d7893b28ca], (This step will run and generate new outputs)
# Submitted PipelineRun 410437fd-0559-43e4-9ecf-6973d097bcb7
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/driver-training-pipeline/runs/410437fd-0559-43e4-9ecf-6973d097bcb7?wsid=/subscriptions/b4f30574-19b5-4753-926d-877888e82fc4/resourcegroups/oh-dsdata-data/workspaces/team5ws
# Pipeline submitted for execution.
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
# PipelineRunId: 410437fd-0559-43e4-9ecf-6973d097bcb7
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/driver-training-pipeline/runs/410437fd-0559-43e4-9ecf-6973d097bcb7?wsid=/subscriptions/b4f30574-19b5-4753-926d-877888e82fc4/resourcegroups/oh-dsdata-data/workspaces/team5ws
# PipelineRun Status: Running
#
#
# StepRunId: a446cd3b-0f32-4c90-8d71-f7b114a226d0
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/driver-training-pipeline/runs/a446cd3b-0f32-4c90-8d71-f7b114a226d0?wsid=/subscriptions/b4f30574-19b5-4753-926d-877888e82fc4/resourcegroups/oh-dsdata-data/workspaces/team5ws
# StepRun( Train Model ) Status: NotStarted
# StepRun( Train Model ) Status: Queued
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# StepRun( Train Model ) Status: Running
# 2020/05/27 12:34:33 Downloading source code...
# 2020/05/27 12:34:34 Finished downloading source code
# 2020/05/27 12:34:34 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/05/27 12:34:35 Successfully set up Docker network: acb_default_network
# 2020/05/27 12:34:35 Setting up Docker configuration...
# 2020/05/27 12:34:36 Successfully set up Docker configuration
# 2020/05/27 12:34:36 Logging in to registry: team5ws7887829e.azurecr.io
# 2020/05/27 12:34:37 Successfully logged into team5ws7887829e.azurecr.io
# 2020/05/27 12:34:37 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/05/27 12:34:37 Scanning for dependencies...
# 2020/05/27 12:34:38 Successfully scanned dependencies
# 2020/05/27 12:34:38 Launching container with name: acb_step_0
# Sending build context to Docker daemon  60.93kB
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
# sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05: Pulling from azureml/base
# Digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
# Status: Downloaded newer image for mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04@sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#  ---> 93a72e6bd1ce
# Step 2/15 : USER root
#  ---> Running in 76d6562019b3
# Removing intermediate container 76d6562019b3
#  ---> 96a7360ed8ed
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in 038beca1b4dd
# Removing intermediate container 038beca1b4dd
#  ---> 966b54bf836b
# Step 4/15 : WORKDIR /
#  ---> Running in c8229a199574
# Removing intermediate container c8229a199574
#  ---> cb85ba2e3d8e
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 77394ffaceb5
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 1c4ff41ae1e8
# Removing intermediate container 1c4ff41ae1e8
#  ---> 5e8981468c13
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 0d5957a2948c
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_37b88f121c458d7f3acf72946d01e394 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 0c004ca6cd1c
# Solving environment: ...working...
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# setuptools-46.4.0    | 646 KB    |            |   0%
# setuptools-46.4.0    | 646 KB    | ########3  |  84%
# setuptools-46.4.0    | 646 KB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | #########3 |  94%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | #######9   |  80%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# numpy-base-1.18.1    | 5.2 MB    |            |   0%
# numpy-base-1.18.1    | 5.2 MB    | #######6   |  76%
# numpy-base-1.18.1    | 5.2 MB    | #########  |  91%
# numpy-base-1.18.1    | 5.2 MB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | #######6   |  77%
# libstdcxx-ng-9.1.0   | 4.0 MB    | #########6 |  96%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# intel-openmp-2020.1  | 940 KB    |            |   0%
# intel-openmp-2020.1  | 940 KB    | ########6  |  87%
# intel-openmp-2020.1  | 940 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# joblib-0.15.1        | 207 KB    |            |   0%
# joblib-0.15.1        | 207 KB    | ########## | 100%
#
# scikit-learn-0.22.1  | 7.1 MB    |            |   0%
# scikit-learn-0.22.1  | 7.1 MB    | #######3   |  73%
# scikit-learn-0.22.1  | 7.1 MB    | #########5 |  95%
# scikit-learn-0.22.1  | 7.1 MB    | ########## | 100%
#
# pandas-1.0.3         | 11.1 MB   |            |   0%
# pandas-1.0.3         | 11.1 MB   | ####4      |  45%
# pandas-1.0.3         | 11.1 MB   | #######5   |  75%
# pandas-1.0.3         | 11.1 MB   | #########2 |  93%
# pandas-1.0.3         | 11.1 MB   | ########## | 100%
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# numpy-1.18.1         | 5 KB      |            |   0%
# numpy-1.18.1         | 5 KB      | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | #####9     |  60%
# libgcc-ng-9.1.0      | 8.1 MB    | #######7   |  77%
# libgcc-ng-9.1.0      | 8.1 MB    | #########3 |  94%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##         |  20%
# python-3.6.2         | 27.0 MB   | ####9      |  50%
# python-3.6.2         | 27.0 MB   | #######5   |  75%
# python-3.6.2         | 27.0 MB   | ########7  |  88%
# python-3.6.2         | 27.0 MB   | #########7 |  97%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# mkl_fft-1.0.15       | 173 KB    |            |   0%
# mkl_fft-1.0.15       | 173 KB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# tk-8.6.8             | 3.1 MB    |            |   0%
# tk-8.6.8             | 3.1 MB    | #######6   |  77%
# tk-8.6.8             | 3.1 MB    | ########9  |  89%
# tk-8.6.8             | 3.1 MB    | #########9 |  99%
# tk-8.6.8             | 3.1 MB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | #######9   |  79%
# ncurses-6.0          | 907 KB    | #########  |  90%

# libgfortran-ng-7.3.0 | 1.3 MB    | ########1  |  81%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
# Downloading and Extracting Packages
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Looking in indexes: https://azuremlsdktestpypi.azureedge.net/sdk-release/Candidate/604C89A437BA41BD942B4F46D9A3591D, https://pypi.python.org/simple
# Collecting azureml-sdk
#   Downloading azureml_sdk-1.6.0-py3-none-any.whl (4.6 kB)
# Collecting azureml-core~=1.6.0
#   Downloading azureml_core-1.6.0-py3-none-any.whl (1.3 MB)
# Collecting azureml-train~=1.6.0
#   Downloading azureml_train-1.6.0-py3-none-any.whl (3.2 kB)
# Collecting azureml-train-automl-client~=1.6.0
#   Downloading azureml_train_automl_client-1.6.0-py3-none-any.whl (88 kB)
# Collecting azureml-dataprep[fuse]<1.7.0a,>=1.6.2a
#   Downloading azureml_dataprep-1.6.3-py3-none-any.whl (27.8 MB)
# Collecting azureml-pipeline~=1.6.0
#   Downloading azureml_pipeline-1.6.0-py3-none-any.whl (3.7 kB)
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading azure_mgmt_authorization-0.60.0-py2.py3-none-any.whl (82 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Requirement already satisfied: pytz in /azureml-envs/azureml_37b88f121c458d7f3acf72946d01e394/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk->-r /azureml-environment-setup/condaenv.5_abevgs.requirements.txt (line 3)) (2020.1)
# Collecting azure-graphrbac>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting PyJWT
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /azureml-envs/azureml_37b88f121c458d7f3acf72946d01e394/lib/python3.6/site-packages (from azureml-core~=1.6.0->azureml-sdk->-r /azureml-environment-setup/condaenv.5_abevgs.requirements.txt (line 3)) (2.8.1)
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting azure-mgmt-resource>=1.2.1
#   Downloading azure_mgmt_resource-9.0.0-py2.py3-none-any.whl (807 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.25-py2.py3-none-any.whl (12 kB)
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading azure_mgmt_storage-10.0.0-py2.py3-none-any.whl (532 kB)
# Collecting azure-mgmt-network~=10.0
#   Downloading azure_mgmt_network-10.2.0-py2.py3-none-any.whl (8.6 MB)
# Collecting pathspec
#   Downloading pathspec-0.8.0-py2.py3-none-any.whl (28 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.1.2-py3-none-any.whl (14 kB)
# Collecting pyopenssl
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7 MB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.1-py2.py3-none-any.whl (36 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.14-py2.py3-none-any.whl (84 kB)
# Collecting docker
#   Downloading docker-4.2.0-py2.py3-none-any.whl (143 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting ruamel.yaml>0.16.7
#   Downloading ruamel.yaml-0.16.10-py2.py3-none-any.whl (111 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.3-py2.py3-none-any.whl (53 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.3-py2.py3-none-any.whl (40 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.25.9-py2.py3-none-any.whl (126 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
# Collecting azureml-train-core~=1.6.0
#   Downloading https://azuremlsdktestpypi.blob.core.windows.net/repo/sdk-release/Candidate/604C89A437BA41BD942B4F46D9A3591D/azureml_train_core-1.6.0.post1-py3-none-any.whl?sv=2018-03-28&sr=b&sig=1djbfQFR1fIK9iKuoWlvT0IyVbO8QUd1ZfKHOCb%2BWPk%3D&st=2020-05-27T00%3A11%3A07Z&se=2021-05-27T00%3A11%3A07Z&sp=rl (8.6 MB)
# Collecting azureml-telemetry~=1.6.0
#   Downloading azureml_telemetry-1.6.0-py3-none-any.whl (29 kB)
# Collecting azureml-automl-core~=1.6.0
#   Downloading azureml_automl_core-1.6.0-py3-none-any.whl (124 kB)
# Collecting azureml-dataprep-native<15.0.0,>=14.1.0
#   Downloading azureml_dataprep_native-14.1.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting cloudpickle>=1.1.0
#   Downloading cloudpickle-1.4.1-py3-none-any.whl (26 kB)
# Collecting azure-identity<1.3.0,>=1.2.0
#   Downloading azure_identity-1.2.0-py2.py3-none-any.whl (58 kB)
# Collecting dotnetcore2>=2.1.14
#   Downloading dotnetcore2-2.1.14-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting fusepy>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting azureml-pipeline-core~=1.6.0
#   Downloading azureml_pipeline_core-1.6.0-py3-none-any.whl (290 kB)
# Collecting azureml-pipeline-steps~=1.6.0
#   Downloading azureml_pipeline_steps-1.6.0-py3-none-any.whl (57 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: six>=1.5 in /azureml-envs/azureml_37b88f121c458d7f3acf72946d01e394/lib/python3.6/site-packages (from python-dateutil>=2.7.3->azureml-core~=1.6.0->azureml-sdk->-r /azureml-environment-setup/condaenv.5_abevgs.requirements.txt (line 3)) (1.14.0)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.4.3-py3-none-any.whl (21 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (399 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-1.6.0-py2.py3-none-any.whl (30 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_37b88f121c458d7f3acf72946d01e394/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.6.0->azureml-sdk->-r /azureml-environment-setup/condaenv.5_abevgs.requirements.txt (line 3)) (2020.4.5.1)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.0-cp36-cp36m-manylinux1_x86_64.whl (548 kB)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.9-py2.py3-none-any.whl (58 kB)
# Collecting azureml-train-restclients-hyperdrive~=1.6.0
#   Downloading azureml_train_restclients_hyperdrive-1.6.0-py3-none-any.whl (18 kB)
# Collecting flake8<=3.7.9,>=3.1.0; python_version >= "3.6"
#   Downloading flake8-3.7.9-py2.py3-none-any.whl (69 kB)
# Collecting applicationinsights
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting msal<2.0.0,>=1.0.0
#   Downloading msal-1.3.0-py2.py3-none-any.whl (48 kB)
# Collecting msal-extensions~=0.1.3
#   Downloading msal_extensions-0.1.3-py2.py3-none-any.whl (9.0 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.5.0-py2.py3-none-any.whl (118 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.1.0-py3-none-any.whl (4.9 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting entrypoints<0.4.0,>=0.3.0
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting pyflakes<2.2.0,>=2.1.0
#   Downloading pyflakes-2.1.1-py2.py3-none-any.whl (59 kB)
# Collecting pycodestyle<2.6.0,>=2.5.0
#   Downloading pycodestyle-2.5.0-py2.py3-none-any.whl (51 kB)
# Collecting mccabe<0.7.0,>=0.6.0
#   Downloading mccabe-0.6.1-py2.py3-none-any.whl (8.6 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.0-py2.py3-none-any.whl (14 kB)
# Building wheels for collected packages: fusepy
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=1601d4de57bdf793ddf6193f8ed6708c0189cf326c15e8a57a2e1017248174a9
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
# Successfully built fusepy
# Installing collected packages: isodate, chardet, idna, urllib3, requests, oauthlib, requests-oauthlib, msrest, PyJWT, pycparser, cffi, cryptography, adal, msrestazure, azure-common, azure-mgmt-authorization, azure-mgmt-containerregistry, azure-graphrbac, pyasn1, pyopenssl, ndg-httpsclient, jmespath, azure-mgmt-keyvault, azure-mgmt-resource, azure-mgmt-storage, azure-mgmt-network, pathspec, backports.weakref, backports.tempfile, jeepney, SecretStorage, zipp, importlib-metadata, jsonpickle, websocket-client, docker, contextlib2, ruamel.yaml.clib, ruamel.yaml, azureml-core, azureml-train-restclients-hyperdrive, entrypoints, pyflakes, pycodestyle, mccabe, flake8, applicationinsights, azureml-telemetry, azureml-train-core, azureml-train, azureml-dataprep-native, cloudpickle, msal, portalocker, msal-extensions, azure-core, azure-identity, distro, dotnetcore2, fusepy, azureml-dataprep, azureml-automl-core, azureml-train-automl-client, azureml-pipeline-core, azureml-pipeline-steps, azureml-pipeline, azureml-sdk
# Successfully installed PyJWT-1.7.1 SecretStorage-3.1.2 adal-1.2.3 applicationinsights-0.11.9 azure-common-1.1.25 azure-core-1.5.0 azure-graphrbac-0.61.1 azure-identity-1.2.0 azure-mgmt-authorization-0.60.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-network-10.2.0 azure-mgmt-resource-9.0.0 azure-mgmt-storage-10.0.0 azureml-automl-core-1.6.0 azureml-core-1.6.0 azureml-dataprep-1.6.3 azureml-dataprep-native-14.1.0 azureml-pipeline-1.6.0 azureml-pipeline-core-1.6.0 azureml-pipeline-steps-1.6.0 azureml-sdk-1.6.0 azureml-telemetry-1.6.0 azureml-train-1.6.0 azureml-train-automl-client-1.6.0 azureml-train-core-1.6.0.post1 azureml-train-restclients-hyperdrive-1.6.0 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.0 chardet-3.0.4 cloudpickle-1.4.1 contextlib2-0.6.0.post1 cryptography-2.9.2 distro-1.5.0 docker-4.2.0 dotnetcore2-2.1.14 entrypoints-0.3 flake8-3.7.9 fusepy-3.0.1 idna-2.9 importlib-metadata-1.6.0 isodate-0.6.0 jeepney-0.4.3 jmespath-0.10.0 jsonpickle-1.4.1 mccabe-0.6.1 msal-1.3.0 msal-extensions-0.1.3 msrest-0.6.14 msrestazure-0.6.3 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pathspec-0.8.0 portalocker-1.7.0 pyasn1-0.4.8 pycodestyle-2.5.0 pycparser-2.20 pyflakes-2.1.1 pyopenssl-19.1.0 requests-2.23.0 requests-oauthlib-1.3.0 ruamel.yaml-0.16.10 ruamel.yaml.clib-0.2.0 urllib3-1.25.9 websocket-client-0.57.0 zipp-3.1.0
#
# #
# # To activate this environment, use:
# # > source activate /azureml-envs/azureml_37b88f121c458d7f3acf72946d01e394
# #
# # To deactivate an active environment, use:
# # > source deactivate
# #
#
#
# Removing intermediate container 0c004ca6cd1c
#  ---> fc59f4957520
# Step 9/15 : ENV PATH /azureml-envs/azureml_37b88f121c458d7f3acf72946d01e394/bin:$PATH
#  ---> Running in e343cfb0da0d
# Removing intermediate container e343cfb0da0d
#  ---> 0a19bbe0bbea
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_37b88f121c458d7f3acf72946d01e394
#  ---> Running in c8a0cc567496
# Removing intermediate container c8a0cc567496
#  ---> 662d11a84717
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_37b88f121c458d7f3acf72946d01e394/lib:$LD_LIBRARY_PATH
#  ---> Running in 3f0ce9c35921
# Removing intermediate container 3f0ce9c35921
#  ---> 4f6b15a0b2f1
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 7a7f9b304822
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit "--repositories" "[]" /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in b710c80ec93d
# Removing intermediate container b710c80ec93d
#  ---> 11748e8cbdc8
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 65a69a1d1b87
# Removing intermediate container 65a69a1d1b87
#  ---> 47e5c05e8ba6
# Step 15/15 : CMD ["bash"]
#  ---> Running in b603816c81ef
# Removing intermediate container b603816c81ef
#  ---> d04f810bd6ce
# Successfully built d04f810bd6ce
# Successfully tagged team5ws7887829e.azurecr.io/azureml/azureml_be3b8acd74e860626700cd80d2081f15:latest
# 2020/05/27 12:39:04 Successfully executed container: acb_step_0
# 2020/05/27 12:39:04 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/05/27 12:39:04 Pushing image: team5ws7887829e.azurecr.io/azureml/azureml_be3b8acd74e860626700cd80d2081f15:latest, attempt 1
# The push refers to repository [team5ws7887829e.azurecr.io/azureml/azureml_be3b8acd74e860626700cd80d2081f15]
# d5694fa54414: Preparing
# 738b18ea9f10: Preparing
# 48e9189ae739: Preparing
# 4b1e8f8bc10f: Preparing
# 2b422378a2e3: Preparing
# c6912104b099: Preparing
# e1171d4d60ca: Preparing
# 6ef1a8ae63b7: Preparing
# 85389f9ead9e: Preparing
# f2608f66a0e3: Preparing
# 0e259b09e5f4: Preparing
# 340dc32eb998: Preparing
# df18b66efaa6: Preparing
# ccdb13a20bf2: Preparing
# 9513cdf4e497: Preparing
# 7f083f9454c0: Preparing
# 29f36b5893dc: Preparing
# f2608f66a0e3: Waiting
# 0e259b09e5f4: Waiting
# 340dc32eb998: Waiting
# df18b66efaa6: Waiting
# ccdb13a20bf2: Waiting
# 9513cdf4e497: Waiting
# 7f083f9454c0: Waiting
# 29f36b5893dc: Waiting
# c6912104b099: Waiting
# e1171d4d60ca: Waiting
# 6ef1a8ae63b7: Waiting
# 85389f9ead9e: Waiting
# d5694fa54414: Pushed
# 48e9189ae739: Pushed
# 2b422378a2e3: Pushed
# 4b1e8f8bc10f: Pushed
# e1171d4d60ca: Pushed
# c6912104b099: Pushed
# 6ef1a8ae63b7: Pushed
# 340dc32eb998: Pushed
# 85389f9ead9e: Pushed
# ccdb13a20bf2: Pushed
# 0e259b09e5f4: Pushed
# 9513cdf4e497: Pushed
# 7f083f9454c0: Pushed
# f2608f66a0e3: Pushed
#
# 29f36b5893dc: Pushed
# df18b66efaa6: Pushed
#
# 738b18ea9f10: Pushed
# latest: digest: sha256:c42a5d2fa508b238c41b9fec408b7435dd75338ecdd3f7240032f7e5160cb256 size: 3883
# 2020/05/27 12:41:17 Successfully pushed image: team5ws7887829e.azurecr.io/azureml/azureml_be3b8acd74e860626700cd80d2081f15:latest
# 2020/05/27 12:41:17 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 266.694517)
# 2020/05/27 12:41:17 Populating digests for step ID: acb_step_0...
# 2020/05/27 12:41:20 Successfully populated digests for step ID: acb_step_0
# 2020/05/27 12:41:20 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 133.741113)
# 2020/05/27 12:41:20 The following dependencies were found:
# 2020/05/27 12:41:20
# - image:
#     registry: team5ws7887829e.azurecr.io
#     repository: azureml/azureml_be3b8acd74e860626700cd80d2081f15
#     tag: latest
#     digest: sha256:c42a5d2fa508b238c41b9fec408b7435dd75338ecdd3f7240032f7e5160cb256
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/base
#     tag: intelmpi2018.3-ubuntu16.04
#     digest: sha256:a1b514f3ba884b9a7695cbba5638933ddaf222e8ce3e8c81e8cdf861679abb05
#   git: {}
#
#
# Run ID: cc1 was successful after 6m48s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_b3751ddb728c626f549fef99b60da79a1abb345f497747eef80b67d06b49e44f_d.txt
# ========================================================================================================================
# 2020-05-27T12:45:45Z Starting output-watcher...
# 2020-05-27T12:45:45Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
#
# Streaming azureml-logs/65_job_prep-tvmps_b3751ddb728c626f549fef99b60da79a1abb345f497747eef80b67d06b49e44f_d.txt
# ===============================================================================================================
# Entering job preparation. Current time:2020-05-27T12:46:36.982977
# Starting job preparation. Current time:2020-05-27T12:46:37.986940
# Extracting the control code.
# fetching and extracting the control code on master node.
# Retrieving project from snapshot: 27df143d-3c8f-4da9-a708-6237794c2e9c
# Starting the daemon thread to refresh tokens in background for process with pid = 57
# Starting project file download.
# Finished project file download.
# downloadDataStore - Download from datastores if requested.
# Entering context manager injector. Current time:2020-05-27T12:46:45.855189
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2020/05/27 12:46:51 Instrumentation Key Is Empty Skipping App Insight Logger
# Entering context manager injector. Current time:2020-05-27T12:46:53.104087
# Starting the daemon thread to refresh tokens in background for process with pid = 119
# Entering Run History Context Manager.
# Preparing to call script [ driver_training.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/team5ws/azureml/a446cd3b-0f32-4c90-8d71-f7b114a226d0/mounts/workspaceblobstore/azureml/a446cd3b-0f32-4c90-8d71-f7b114a226d0/model_folder']
# After variable expansion, calling script [ driver_training.py ] with arguments: ['--output_folder', '/mnt/batch/tasks/shared/LS_root/jobs/team5ws/azureml/a446cd3b-0f32-4c90-8d71-f7b114a226d0/mounts/workspaceblobstore/azureml/a446cd3b-0f32-4c90-8d71-f7b114a226d0/model_folder']
# [241]	valid_0's auc: 0.637682
# [242]	valid_0's auc: 0.637751
# [243]	valid_0's auc: 0.637722
# [244]	valid_0's auc: 0.637714
# [245]	valid_0's auc: 0.637647
# [246]	valid_0's auc: 0.637679
# [247]	valid_0's auc: 0.637679
# [248]	valid_0's auc: 0.637735
# [249]	valid_0's auc: 0.6377
# [250]	valid_0's auc: 0.637738
# [251]	valid_0's auc: 0.637708
# [252]	valid_0's auc: 0.637688
# [253]	valid_0's auc: 0.637725
# [254]	valid_0's auc: 0.637697
# [255]	valid_0's auc: 0.637689
# [256]	valid_0's auc: 0.637714
# [257]	valid_0's auc: 0.637688
# [258]	valid_0's auc: 0.637732
# [259]	valid_0's auc: 0.637703
# [260]	valid_0's auc: 0.63775
# [261]	valid_0's auc: 0.637715
# [262]	valid_0's auc: 0.637711
# Early stopping, best iteration is:
# [242]	valid_0's auc: 0.637751
# {'auc': 0.6377511613946426}
# Starting the daemon thread to refresh tokens in background for process with pid = 119
#
#
# The experiment completed successfully. Finalizing run...
#
# Streaming azureml-logs/75_job_post-tvmps_b3751ddb728c626f549fef99b60da79a1abb345f497747eef80b67d06b49e44f_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-05-27T12:47:11.043195
# Starting job release. Current time:2020-05-27T12:47:12.837017
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 185
# Entering context manager injector. Current time:2020-05-27T12:47:12.857622
# Job release is complete. Current time:2020-05-27T12:47:15.363665
#
# StepRun(Train Model) Execution Summary
# =======================================
# StepRun( Train Model ) Status: Finished
# {'runId': 'a446cd3b-0f32-4c90-8d71-f7b114a226d0', 'target': 'team5hacker2', 'status': 'Completed', 'startTimeUtc': '2020-05-27T12:45:41.069112Z', 'endTimeUtc': '2020-05-27T12:47:17.763516Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '27df143d-3c8f-4da9-a708-6237794c2e9c', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '7003a134-8b49-4efb-9382-25bd7973ad52', 'azureml.pipelinerunid': '410437fd-0559-43e4-9ecf-6973d097bcb7', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '4a0c1bcb-ac13-402c-82be-071950386e3b'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'driver_train', 'mechanism': 'Direct'}}], 'runDefinition': {'script': 'driver_training.py', 'useAbsolutePath': False, 'arguments': ['--output_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'team5hacker2', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/a446cd3b-0f32-4c90-8d71-f7b114a226d0/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'driver_train': {'dataLocation': {'dataset': {'id': '4a0c1bcb-ac13-402c-82be-071950386e3b'}, 'dataPath': None}, 'createOutputDirectories': False, 'mechanism': 'Direct', 'environmentVariableName': 'driver_train', 'pathOnCompute': None, 'overwrite': False}}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment driver-training-pipeline Environment', 'version': 'Autosave_2020-05-27T12:34:24Z_9a78c0b7', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['--index-url https://azuremlsdktestpypi.azureedge.net/sdk-release/Candidate/604C89A437BA41BD942B4F46D9A3591D', '--extra-index-url https://pypi.python.org/simple', 'azureml-sdk']}, 'scikit-learn', 'pandas', 'lightgbm'], 'name': 'azureml_37b88f121c458d7f3acf72946d01e394'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04', 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'shmSize': '1g'}, 'spark': {'repositories': ['[]'], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '1g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'itpCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://team5ws3141506676.blob.core.windows.net/azureml/ExperimentRun/dcid.a446cd3b-0f32-4c90-8d71-f7b114a226d0/azureml-logs/20_image_build_log.txt?sv=2019-02-02&sr=b&sig=8HAo7lcg%2FfM3%2FuOXzgPZgbOhMfeJICHju0DBKtc49AU%3D&st=2020-05-27T12%3A37%3A21Z&se=2020-05-27T20%3A47%3A21Z&sp=r', 'azureml-logs/55_azureml-execution-tvmps_b3751ddb728c626f549fef99b60da79a1abb345f497747eef80b67d06b49e44f_d.txt': 'https://team5ws3141506676.blob.core.windows.net/azureml/ExperimentRun/dcid.a446cd3b-0f32-4c90-8d71-f7b114a226d0/azureml-logs/55_az ...
#
#
#
#
# StepRunId: 7ffe9c74-9159-422f-8727-0a17f1f92f41
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/driver-training-pipeline/runs/7ffe9c74-9159-422f-8727-0a17f1f92f41?wsid=/subscriptions/b4f30574-19b5-4753-926d-877888e82fc4/resourcegroups/oh-dsdata-data/workspaces/team5ws
# StepRun( Register Model ) Status: NotStarted
# StepRun( Register Model ) Status: Running
#
# Streaming azureml-logs/65_job_prep-tvmps_b3751ddb728c626f549fef99b60da79a1abb345f497747eef80b67d06b49e44f_d.txt
# ===============================================================================================================
# Entering job preparation. Current time:2020-05-27T12:47:44.084336
# Starting job preparation. Current time:2020-05-27T12:47:44.793742
# Extracting the control code.
# fetching and extracting the control code on master node.
# Retrieving project from snapshot: 27df143d-3c8f-4da9-a708-6237794c2e9c
# Starting the daemon thread to refresh tokens in background for process with pid = 56
# Starting project file download.
# Finished project file download.
# downloadDataStore - Download from datastores if requested.
# Entering context manager injector. Current time:2020-05-27T12:47:51.490464
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2020/05/27 12:47:54 Instrumentation Key Is Empty Skipping App Insight Logger
# Entering context manager injector. Current time:2020-05-27T12:47:55.998055
# Starting the daemon thread to refresh tokens in background for process with pid = 118
# Entering Run History Context Manager.
# Preparing to call script [ register_model.py ] with arguments: ['--model_folder', '/mnt/batch/tasks/shared/LS_root/jobs/team5ws/azureml/7ffe9c74-9159-422f-8727-0a17f1f92f41/mounts/workspaceblobstore/azureml/a446cd3b-0f32-4c90-8d71-f7b114a226d0/model_folder']
# After variable expansion, calling script [ register_model.py ] with arguments: ['--model_folder', '/mnt/batch/tasks/shared/LS_root/jobs/team5ws/azureml/7ffe9c74-9159-422f-8727-0a17f1f92f41/mounts/workspaceblobstore/azureml/a446cd3b-0f32-4c90-8d71-f7b114a226d0/model_folder']
#
# Loading model from /mnt/batch/tasks/shared/LS_root/jobs/team5ws/azureml/7ffe9c74-9159-422f-8727-0a17f1f92f41/mounts/workspaceblobstore/azureml/a446cd3b-0f32-4c90-8d71-f7b114a226d0/model_folder
# Registering model driver_model
# Starting the daemon thread to refresh tokens in background for process with pid = 118
#
#
# The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 2 items cleaning up...
# Cleanup took 0.21607708930969238 seconds
#
# Streaming azureml-logs/75_job_post-tvmps_b3751ddb728c626f549fef99b60da79a1abb345f497747eef80b67d06b49e44f_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-05-27T12:48:07.941023
# Starting job release. Current time:2020-05-27T12:48:10.046487
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 187
# Entering context manager injector. Current time:2020-05-27T12:48:10.068305
# Job release is complete. Current time:2020-05-27T12:48:13.802696
#
# StepRun(Register Model) Execution Summary
# ==========================================
# StepRun( Register Model ) Status: Finished
# {'runId': '7ffe9c74-9159-422f-8727-0a17f1f92f41', 'target': 'team5hacker2', 'status': 'Completed', 'startTimeUtc': '2020-05-27T12:47:46.17692Z', 'endTimeUtc': '2020-05-27T12:48:17.329718Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '27df143d-3c8f-4da9-a708-6237794c2e9c', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '570e562e-9f5a-4694-aa4d-49d7893b28ca', 'azureml.pipelinerunid': '410437fd-0559-43e4-9ecf-6973d097bcb7', '_azureml.ComputeTargetType': 'amlcompute', 'AzureML.DerivedImageName': 'azureml/azureml_be3b8acd74e860626700cd80d2081f15', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'runDefinition': {'script': 'register_model.py', 'useAbsolutePath': False, 'arguments': ['--model_folder', '$AZUREML_DATAREFERENCE_model_folder'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'team5hacker2', 'dataReferences': {'model_folder': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/a446cd3b-0f32-4c90-8d71-f7b114a226d0/model_folder', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment driver-training-pipeline Environment', 'version': 'Autosave_2020-05-27T12:34:24Z_9a78c0b7', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['--index-url https://azuremlsdktestpypi.azureedge.net/sdk-release/Candidate/604C89A437BA41BD942B4F46D9A3591D', '--extra-index-url https://pypi.python.org/simple', 'azureml-sdk']}, 'scikit-learn', 'pandas', 'lightgbm'], 'name': 'azureml_37b88f121c458d7f3acf72946d01e394'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/base:intelmpi2018.3-ubuntu16.04', 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'shmSize': '1g'}, 'spark': {'repositories': ['[]'], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '1g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'itpCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_b3751ddb728c626f549fef99b60da79a1abb345f497747eef80b67d06b49e44f_d.txt': 'https://team5ws3141506676.blob.core.windows.net/azureml/ExperimentRun/dcid.7ffe9c74-9159-422f-8727-0a17f1f92f41/azureml-logs/55_azureml-execution-tvmps_b3751ddb728c626f549fef99b60da79a1abb345f497747eef80b67d06b49e44f_d.txt?sv=2019-02-02&sr=b&sig=GxPBAeJSi1qoKy1adPeE2U6ojpABiq43%2BsZbcoqX93k%3D&st=2020-05-27T12%3A38%3A20Z&se=2020-05-27T20%3A48%3A20Z&sp=r', 'azureml-logs/65_job_prep-tvmps_b3751ddb728c626f549fef99b60da79a1abb345f497747eef80b67d06b49e44f_d.txt': 'https://team5ws3141506676.blob.core.windows.net/azureml/ExperimentRun/dcid.7ffe9c74-9159-422f-8727-0a17f1f92f41/azureml-logs/65_job_prep-tvmps_b3751ddb728c626f549fef99b60da79a1abb345f497747eef80b67d06b49e44f_d.txt?sv=2019-02-02&sr=b&sig=L58dbbRCZgZAxmdMFelxNcKx%2FCKXd3tZWDY%2BBVKQ7AM%3D&st=2020-05-27T12%3A38%3A20Z&se=2020 ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '410437fd-0559-43e4-9ecf-6973d097bcb7', 'status': 'Completed', 'startTimeUtc': '2020-05-27T12:33:42.695253Z', 'endTimeUtc': '2020-05-27T12:48:19.671901Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://team5ws3141506676.blob.core.windows.net/azureml/ExperimentRun/dcid.410437fd-0559-43e4-9ecf-6973d097bcb7/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=NKSjQSZP%2BMUte6zBn8s0Nf32QUtaSQhvp2Y%2FVJJr%2BxE%3D&st=2020-05-27T12%3A38%3A22Z&se=2020-05-27T20%3A48%3A22Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://team5ws3141506676.blob.core.windows.net/azureml/ExperimentRun/dcid.410437fd-0559-43e4-9ecf-6973d097bcb7/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=4u3USZQcudBbDC96fE3PIo5E5UdN%2B9ULqdkLvhue0N4%3D&st=2020-05-27T12%3A38%3A22Z&se=2020-05-27T20%3A48%3A22Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://team5ws3141506676.blob.core.windows.net/azureml/ExperimentRun/dcid.410437fd-0559-43e4-9ecf-6973d097bcb7/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=cpcsu%2F8CyTRf2Rv2S2xX79i5gcKVm6xLPt3fXXOICkM%3D&st=2020-05-27T12%3A38%3A22Z&se=2020-05-27T20%3A48%3A22Z&sp=r'}}
# 'Finished'

# %%
# Print the model name, version, tag, and properties
from azureml.core import Model

for model in Model.list(ws):
    print(model.name, 'version:', model.version)
    for tag_name in model.tags:
        tag = model.tags[tag_name]
        print ('\t',tag_name, ':', tag)
    for prop_name in model.properties:
        prop = model.properties[prop_name]
        print ('\t',prop_name, ':', prop)
    print('\n')
# Out:
# driver_model version: 1
# 	 Training context : Pipeline
#
#
# driver_model.pkl version: 12
# 	 auc : 0.6377511613946426
#
#
# driver_model.pkl version: 11
# 	 auc : 0.6380025131414137
#
#
# driver_model.pkl version: 10
# 	 metrics : {'driver-training_1590531244_e6526452': {'learning_rate': 0.04, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'sub_feature': 0.7, 'num_leaves': 60, 'min_data': 100, 'verbose': 0, 'min_hessian': 1, 'auc': 0.6380025131414137}}
#
#
# driver_model.pkl version: 9
# 	 metrics : {'driver-training_1590530540_fe469c8e': {'learning_rate': 0.02, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'num_leaves': 60, 'sub_feature': 0.7, 'verbose': 0, 'min_hessian': 1, 'min_data': 100, 'auc': 0.6377511613946426}}
#
#
# driver_model.pkl version: 8
# 	 auc : {'driver-training_1590530540_fe469c8e': {'learning_rate': 0.02, 'boosting_type': 'gbdt', 'objective': 'binary', 'metric': 'auc', 'num_leaves': 60, 'sub_feature': 0.7, 'verbose': 0, 'min_hessian': 1, 'min_data': 100, 'auc': 0.6377511613946426}}
#
#
# driver_model.pkl version: 7
# 	 auc : auc
#
#
# driver_model.pkl version: 6
# 	 auc : a
#
#
# driver_model.pkl version: 5
# 	 auc : auc
#
#
# driver_model.pkl version: 4
# 	 Training context : Pipeline
#
#
# driver_model.pkl version: 3
#
#
# driver_model.pkl version: 2
#
#
# driver_model.pkl version: 1
